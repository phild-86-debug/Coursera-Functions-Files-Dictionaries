# %% [markdown]
# # Sorting with sort and sorted 16.1

# %%
# sort retrns None.  sort modifies the list(creates side effect)
# sort does not return a sorted version of the list
l1 = [1, 7, 4, -2, 3]
l2 = ["cherry", "apple", "blueberry"]

l1.sort()
print(l1)
l2.sort()
print(l2)
# Out:
# [-2, 1, 3, 4, 7]
# ['apple', 'blueberry', 'cherry']

# %% [markdown]
# ## using sorted instead of sort
# sort = method:  mutates the list <br>
# sorted = function:  does not mutate the original list. Instead sorted returns a new list
# <br>
# > In this course, we will generally use an alternative way of sorting,
# the function sorted rather than the method sort. Because it is a function rather than a method,
# it is invoked on a list by passing the list as a parameter inside the parentheses,
# rather than putting the list before the period. More importantly, sorted does not change the original list.
# Instead, it returns a new list.

# %%
L2 = ["Cherry", "Apple", "Blueberry"]

L3 = sorted(L2)
print(L3)
print(sorted(L2))
print(L2) # unchanged
 
print("----")

L2.sort()
print(L2)
print(L2.sort())  #return value is None
# Out:
# ['Apple', 'Blueberry', 'Cherry']
# ['Apple', 'Blueberry', 'Cherry']
# ['Cherry', 'Apple', 'Blueberry']
# ----
# ['Apple', 'Blueberry', 'Cherry']
# None
